# %%
# %load_ext autoreload

# %autoreload 2
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.svm import SVC
from sklearn.metrics import roc_auc_score, roc_curve

from sklearn import preprocessing
from sklearn.linear_model import LogisticRegression
from sklearn.decomposition import PCA
from sklearn import metrics

from keras.models import Sequential
from keras.layers import Dense, Dropout, regularizers
from keras.layers import LSTM


from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers.embeddings import Embedding
from keras.preprocessing import sequence


import warnings
import numpy as np
from collections import OrderedDict

import os

from lob_data_utils import lob, db_result, gdf_pca, model
from lob_data_utils.svm_calculation import lob_svm


sns.set_style('whitegrid')
warnings.filterwarnings('ignore')
# Out:
# Using TensorFlow backend.

# %%
data_length = 24000
stock = '4320'
gdf_filename_pattern = 'gdf_{}_r{}_s{}_K50'
gdf_parameters = [(0.1, 0.1), (0.01, 0.1), (0.1, 0.5), (0.01, 0.5)]

# %%
df_log = pd.read_csv('../../gdf_pca/res_log_que.csv')   
df_log = df_log[df_log['stock'] == int(stock)]
columns = [c for c in df_log.columns if 'matthews' in c or 'roc_auc' in c]
df_log[columns]
# Out:
#     matthews  roc_auc  test_matthews  test_roc_auc  train_matthews  \
# 85  0.135224  0.57364       0.133149      0.572081        0.142469
#
#     train_roc_auc  train_val_matthews  train_val_roc_auc
# 85       0.576916             0.16192           0.587331

# %%
gdf_dfs = []
for r, s in gdf_parameters:
    gdf_dfs.append(gdf_pca.SvmGdfResults(
        stock,  r=r, s=s, data_length=data_length, data_dir='../../data/data_gdf',
        reg_data_dir='../../data/prepared',
        gdf_filename_pattern=gdf_filename_pattern))

# %%
df = gdf_dfs[2].df
df_test = gdf_dfs[2].df_test
n_components = gdf_dfs[2].get_pca('pca_n_gdf_que_prev').n_components_
class_weights = gdf_dfs[2].get_classes_weights()
print(n_components, class_weights)
# Out:
# 5 {0.0: 0.7255857898715041, 1.0: 1.6082258334729436}

# %%
df[[c for c in df.columns if 'gdf' in c]].boxplot(figsize=(16, 4))

# %%
def as_keras_metric(method):
    import functools
    from keras import backend as K
    import tensorflow as tf
    @functools.wraps(method)
    def wrapper(self, args, **kwargs):
        """ Wrapper for turning tensorflow metrics into keras metrics """
        value, update_op = method(self, args, **kwargs)
        K.get_session().run(tf.local_variables_initializer())
        with tf.control_dependencies([update_op]):
            value = tf.identity(value)
        return value
    return wrapper
import tensorflow as tf
auc_roc = as_keras_metric(tf.metrics.auc)

# %%
## With validation

# %%
model = Sequential()
model.add(LSTM(32, input_shape=(5, 7)))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=[auc_roc])

# %%
epochs = 3
batch_size = 10
score = gdf_dfs[0].train_lstm(
    model, feature_name='pca_n_gdf_que', plot_name='here.png', n_steps=5,
    fit_kwargs={'epochs': epochs, 'batch_size': batch_size, 'verbose': 1, 'shuffle': False}, 
    class_weight=class_weights,
    compile_kwargs= { 'loss': 'binary_crossentropy', 'optimizer': 'adam', 'metrics': [auc_roc]})
# Out:
# Training fold  5 19195
# train:  0 8725
# val: 8725 12215
# Train on 8725 samples, validate on 3490 samples
# Epoch 1/3
# 8725/8725 [==============================] - 7s 775us/step - loss: 0.6889 - auc: 0.5612 - val_loss: 0.6869 - val_auc: 0.5892
# Epoch 2/3
# 8725/8725 [==============================] - 7s 850us/step - loss: 0.6816 - auc: 0.5912 - val_loss: 0.6780 - val_auc: 0.5997
# Epoch 3/3
# 8725/8725 [==============================] - 5s 539us/step - loss: 0.6805 - auc: 0.6005 - val_loss: 0.6724 - val_auc: 0.6049
# Training fold  6 19195
# train:  1745 10470
# val: 10470 13960
# Train on 8725 samples, validate on 3490 samples
# Epoch 1/3
# 8725/8725 [==============================] - 5s 542us/step - loss: 0.6692 - auc: 0.6132 - val_loss: 0.6616 - val_auc: 0.6222
# Epoch 2/3
# 8725/8725 [==============================] - 5s 541us/step - loss: 0.6695 - auc: 0.6174 - val_loss: 0.6624 - val_auc: 0.6195
# Epoch 3/3
# 8725/8725 [==============================] - 5s 594us/step - loss: 0.6693 - auc: 0.6175 - val_loss: 0.6628 - val_auc: 0.6189
# Training fold  7 19195
# train:  3490 12215
# val: 12215 15705
# Train on 8725 samples, validate on 3490 samples
# Epoch 1/3
# 8725/8725 [==============================] - 5s 527us/step - loss: 0.6583 - auc: 0.6191 - val_loss: 0.6792 - val_auc: 0.6209
# Epoch 2/3
# 8725/8725 [==============================] - 3s 389us/step - loss: 0.6581 - auc: 0.6209 - val_loss: 0.6783 - val_auc: 0.6207
# Epoch 3/3
# 8725/8725 [==============================] - 5s 534us/step - loss: 0.6578 - auc: 0.6210 - val_loss: 0.6778 - val_auc: 0.6210
# Training fold  8 19195
# train:  5235 13960
# val: 13960 17450
# Train on 8725 samples, validate on 3490 samples
# Epoch 1/3
# 8725/8725 [==============================] - 6s 679us/step - loss: 0.6648 - auc: 0.6283 - val_loss: 0.6868 - val_auc: 0.6205
# Epoch 2/3
# 8725/8725 [==============================] - 4s 404us/step - loss: 0.6644 - auc: 0.6205 - val_loss: 0.6873 - val_auc: 0.6192
# Epoch 3/3
# 8725/8725 [==============================] - 3s 369us/step - loss: 0.6642 - auc: 0.6195 - val_loss: 0.6879 - val_auc: 0.6190
# Training fold  9 19195
# train:  6980 15705
# val: 15705 19195
# Train on 8725 samples, validate on 3490 samples
# Epoch 1/3
# 8725/8725 [==============================] - 7s 811us/step - loss: 0.6597 - auc: 0.6190 - val_loss: 0.6698 - val_auc: 0.6172
# Epoch 2/3
# 8725/8725 [==============================] - 3s 399us/step - loss: 0.6592 - auc: 0.6175 - val_loss: 0.6699 - val_auc: 0.6159
# Epoch 3/3
# 8725/8725 [==============================] - 5s 605us/step - loss: 0.6588 - auc: 0.6166 - val_loss: 0.6700 - val_auc: 0.6158
# Train on 19195 samples, validate on 3490 samples
# Epoch 1/3
# 19195/19195 [==============================] - 13s 697us/step - loss: 0.6733 - auc: 0.6149 - val_loss: 0.6784 - val_auc: 0.6140
# Epoch 2/3
# 19195/19195 [==============================] - 17s 879us/step - loss: 0.6727 - auc: 0.6140 - val_loss: 0.6771 - val_auc: 0.6137
# Epoch 3/3
# 19195/19195 [==============================] - 20s 1ms/step - loss: 0.6725 - auc: 0.6138 - val_loss: 0.6762 - val_auc: 0.6137
# Epoch 1/3
# 19195/19195 [==============================] - 27s 1ms/step - loss: 0.6723 - auc: 0.6123
# Epoch 2/3
# 19195/19195 [==============================] - 29s 2ms/step - loss: 0.6721 - auc: 0.6164
# Epoch 3/3
# 19195/19195 [==============================] - 26s 1ms/step - loss: 0.6720 - auc: 0.6167

# %%
score['matthews'], score['test_matthews'], score['roc_auc'], score['test_roc_auc']
# Out:
# (0.1360973184695584,
#  0.13775273668554477,
#  0.5737766182793169,
#  0.5744123302940437)

# %%
score = {**score, 'arch': model.to_json(), 'batch_size': batch_size, 'n_steps': 5, 'epochs': epochs, 
         'r': gdf_dfs[0].r, 's': gdf_dfs[0].s}
pd.DataFrame([score]).to_csv(
    '../../gdf_pca/res_lstm_weird/res_lstm_pca_que_{}_len24000_r{}_s{}.csv'.format(stock, gdf_dfs[0].r, gdf_dfs[0].s))
