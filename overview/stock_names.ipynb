# %%
import pandas as pd

# %%
df_s = pd.read_csv('stocks.csv')

# %%
df = pd.read_csv('../stocks_names.csv')

df = pd.merge(df, df_s, on='stock')
df
# Out:
#     stock     weird_num   set captial something                       name  \
# 0    9061  GB0005405286  SET0      GB       GBX              HSBC Holdings
# 1    3459  GB00B08SNH34  SET1      GB       GBX          National Grid plc
# 2    2822  GB0033277061  SET1      GB       GBX      Vedanta Resources plc
# 3    9761  GB0000595859  SET1      GB       GBX           ARM Holdings plc
# 4    4851  GB00B39J2M42  SET1      GB       GBX           United Utilities
# 5    9062  GB0007188757  SET0      GB       GBX                  Rio Tinto
# 6    3879  GB00B10RZP78  SET1      GB       GBX                   Unilever
# 7    1431  GB0002405495  SET1      GB       GBX              Schroders PLC
# 8    2748  GB0032089863  SET1      GB       GBX                       Next
# 9    4320  GB00B1KJJ408  SET1      GB       GBX                  Whitbread
# 10  11583  GB0002374006  SET0      GB       GBX                     Diageo
# ...

# %%
df.columns
# Out:
# Index(['stock', 'weird_num', 'set', 'captial', 'something', 'name',
#        'short_name', 'Unnamed: 0', 'mean_mid_price', 'mean_spread',
#        'mid_price_indicator_ratio', 'test_dates', 'test_length',
#        'test_mean_mid_price', 'test_mean_spread',
#        'test_mid_price_indicator_ratio', 'test_set_length', 'train_dates',
#        'train_length', 'train_set_length', 'diff_mean_mid_price',
#        'diff_mid_price_indicator_ratio', 'diff_mean_spread', 'km',
#        'is_choosen'],
#       dtype='object')

# %%
print(df.sort_values(by='km')[['stock', 'short_name', 'mean_spread', 'mean_mid_price']].to_latex())
# Out:
# \begin{tabular}{lrlrr}
# \toprule
# {} &  stock & short\_name &  mean\_spread &  mean\_mid\_price \\
# \midrule
# 0  &   9061 &        HSB &     0.167577 &      686.151230 \\
# 1  &   3459 &        NGG &     0.646266 &      752.117731 \\
# 3  &   9761 &        ARM &     0.939125 &      973.908411 \\
# 4  &   4851 &         UU &     0.769056 &      696.995186 \\
# 12 &   2730 &       LAND &     0.776235 &      934.176676 \\
# 5  &   9062 &        RIO &     0.966438 &     3120.336399 \\
# 6  &   3879 &       ULVR &     1.200665 &     2456.725912 \\
# 7  &   1431 &        SDR &     2.329788 &     2553.911820 \\
# 8  &   2748 &        NXT &     5.644103 &     5128.616356 \\
# 9  &   4320 &        WTB &     1.890978 &     3150.772656 \\
# 2  &   2822 &        VED &     1.901099 &     1102.788002 \\
# 10 &  11583 &        DGE &     0.780740 &     1984.517965 \\
# 11 &   4799 &       FRES &     1.743972 &     1041.757428 \\
# 13 &  10470 &       WEIR &     1.805948 &     2314.327218 \\
# ...
