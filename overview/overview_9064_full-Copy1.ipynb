# %%
# %load_ext autoreload

# %autoreload 2
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.svm import SVC
from sklearn.metrics import roc_auc_score, roc_curve

from sklearn import preprocessing
from sklearn.linear_model import LogisticRegression
from sklearn.decomposition import PCA

import warnings
import numpy as np
from collections import OrderedDict

import os

from lob_data_utils import lob, db_result, gdf_pca, model
from lob_data_utils.svm_calculation import lob_svm


sns.set_style('whitegrid')
warnings.filterwarnings('ignore')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data_length = 15000
stock = '9064'
gdf_filename_pattern = 'gdf_{}_' + 'len{}'.format(data_length) + '_r{}_s{}_K50'
gdf_parameters = [(1.0, 1.0), (0.1, 0.1), (0.1, 1.0), (1.0, 0.1)]

# %%
gdf_dfs = []
for r, s in gdf_parameters:
    gdf_dfs.append(gdf_pca.SvmGdfResults(
        stock,  r=r, s=s, data_length=data_length, 
        gdf_filename_pattern=gdf_filename_pattern))

# %% [markdown]
# ## Visualization
#
# What do I want to say here?
#
# * that data is quite random
# * distribution of queue imbalance
# * that there is some correlation between queue imbalance and mid price indicator
# * show some gdf values

# %%
df = gdf_dfs[2].df

# %% [markdown]
# ### Mid Price
#
# Data is quite random, there are outliers

# %%
fig, ax = plt.subplots(figsize=(16, 8))

df[['bid_price']].plot(ax=ax, alpha=0.75, linestyle='--')
df[['ask_price']].plot(ax=ax, alpha=0.75, linestyle='--')
df[['mid_price']].plot(ax=ax, alpha=0.5)
plt.legend(['Bid-Price', 'Ask-Price', 'Mid-Price',])
plt.ylabel('Price')
plt.xlabel('')
plt.title('Mid-Price for {} for training dataset'.format(stock))
# Out:
# Text(0.5,1,'Mid-Price for 9061 for training dataset')

# %% [markdown]
# We can observe outliers, lets look into them - both are around 11 Fridays

# %%
fig, ax = plt.subplots(figsize=(16, 8))
df[['bid_price']].loc['2013-09-20'].plot(ax=ax, alpha=0.75, linestyle='--')
df[['ask_price']].loc['2013-09-20'].plot(ax=ax, alpha=0.75, linestyle='--')
df[['mid_price']].loc['2013-09-20'].plot(ax=ax, alpha=0.5)

# %%
fig, ax = plt.subplots(figsize=(16, 8))
df[['bid_price']].loc['2013-10-18'].plot(ax=ax, alpha=0.75, linestyle='--')
df[['ask_price']].loc['2013-10-18'].plot(ax=ax, alpha=0.75, linestyle='--')
df[['mid_price']].loc['2013-10-18'].plot(ax=ax, alpha=0.5)

# %% [markdown]
# ### Distributions

# %%
fig, ax = plt.subplots(1, 3, figsize=(16, 4))
sns.distplot(df['mid_price_indicator'], ax=ax[0])
sns.distplot(df['queue_imbalance'], ax=ax[1])
sns.distplot(df['mid_price'], ax=ax[2])
sns.distplot(df['ask_price'], ax=ax[2])
sns.distplot(df['bid_price'], ax=ax[2])
df['mid_price'].mean(), df['mid_price'].median(), df['mid_price'].mode()
# Out:
# (76.02602175181232, 75.89, 0    74.985
#  1    75.990
#  dtype: float64)

# %% [markdown]
# Distribution of Mid-Price Indidcator is balanced (classes are balanced). Mid-Price distribution is slightly Right-Skewed.

# %%
plt.figure(figsize=(8, 8))
sns.kdeplot(df['mid_price'], df['queue_imbalance'], cbar=True, shade=True)
df['mid_price'].mean(), df['mid_price'].median(), df['mid_price'].mode()
# Out:
# (76.02602175181232, 75.89, 0    74.985
#  1    75.990
#  dtype: float64)

# %% [markdown]
# We can see that for queue imbalance -1 or 1 the density is the smallest. The highest density for queue imbalance in between -0.5 and 0.5 which happens to be around the mean mid price

# %% [markdown]
# ### Correlations

# %%
cols = ['gdf_1', 'gdf_23', 'gdf_25', 'queue_imbalance', 'prev_queue_imbalance', 
        'mid_price', 'mid_price_indicator', 'next_mid_price']
sns.heatmap(df[cols].corr(), annot=True)
# TODO: ?

# %%
### GDF

# %%
n_components = 2
pca = PCA(n_components=n_components)
gdf_columns = ['gdf_' + str(i) for i in range(0, 50)]
p = pca.fit_transform(df[gdf_columns])

for i in range(n_components):
    df['pca' + str(i)] = p[:, i]
pca_cols = ['pca' + str(i) for i in range(n_components)]

cols = ['gdf_23', 'gdf_25', 'queue_imbalance',
        'mid_price', 'mid_price_indicator']
df[pca_cols].plot()

# %%
sns.heatmap(df[pca_cols + ['mid_price_indicator', 'queue_imbalance']].corr(), annot=True)

# %%
df[['gdf_0', 'gdf_24', 'gdf_49']].plot()

# %%
fig, ax = plt.subplots(2, 1, figsize=(16, 8), sharex=True)
df[gdf_columns].iloc[0].plot('bar', color=['b'], alpha=0.5, ax=ax[0])
df[gdf_columns].iloc[2003].plot('bar', color=['b'], alpha=0.5, ax=ax[1])
ax[0].set_title(df['mid_price_indicator'].iloc[0])
ax[1].set_title(df['mid_price_indicator'].iloc[2003])
# Out:
# Text(0.5,1,'0.0')

# %%
fig, ax = plt.subplots(2, 1, figsize=(16, 8), sharex=True)
df[pca_cols].iloc[0].plot('bar', color=['b'], alpha=0.5, ax=ax[0])
df[pca_cols].iloc[2003].plot('bar', color=['b'], alpha=0.5, ax=ax[1])
ax[0].set_title(df['mid_price_indicator'].iloc[0])
ax[1].set_title(df['mid_price_indicator'].iloc[2003])
# Out:
# Text(0.5,1,'0.0')

# %%
df.head()
# Out:
#                      Unnamed: 0     gdf_0     gdf_1    gdf_10    gdf_11  \
# datetime
# 2013-09-12 14:43:00        3002  0.067212  0.067827  0.083826  0.087539
# 2013-09-12 14:44:00        3003  0.068146  0.071077  0.087577  0.090302
# 2013-09-12 14:45:00        3004  0.090087  0.091746  0.088914  0.089031
# 2013-09-12 14:46:00        3005  0.078952  0.079602  0.089263  0.090763
# 2013-09-12 14:47:00        3006  0.100243  0.099539  0.096626  0.094999
#
#                        gdf_12    gdf_13    gdf_14    gdf_15    gdf_16  \
# datetime
# 2013-09-12 14:43:00  0.090337  0.093438  0.095575  0.097320  0.098497
# 2013-09-12 14:44:00  0.093650  0.096161  0.098431  0.100396  0.101838
# 2013-09-12 14:45:00  0.088152  0.087411  0.087095  0.086741  0.086606
# 2013-09-12 14:46:00  0.091573  0.091193  0.089679  0.088365  0.087200
# 2013-09-12 14:47:00  0.092772  0.091110  0.089321  0.087839  0.086697
#
#                        ...     mid_price  mid_price_indicator  \
# datetime               ...
# 2013-09-12 14:43:00    ...        75.505                  1.0
# 2013-09-12 14:44:00    ...        75.510                  1.0
# 2013-09-12 14:45:00    ...        75.615                  0.0
# 2013-09-12 14:46:00    ...        75.570                  1.0
# 2013-09-12 14:47:00    ...        75.630                  0.0
#
#                                 datetime  bid_price  ask_price  \
# datetime
# 2013-09-12 14:43:00  2013-09-12 14:43:00      75.49      75.52
# 2013-09-12 14:44:00  2013-09-12 14:44:00      75.49      75.53
# 2013-09-12 14:45:00  2013-09-12 14:45:00      75.60      75.63
# 2013-09-12 14:46:00  2013-09-12 14:46:00      75.55      75.59
# 2013-09-12 14:47:00  2013-09-12 14:47:00      75.62      75.64
#
#                      queue_imbalance  prev_queue_imbalance  next_mid_price  \
# datetime
# 2013-09-12 14:43:00        -0.021731             -0.750835          75.510
# 2013-09-12 14:44:00         0.881878             -0.021731          75.505
# 2013-09-12 14:45:00        -0.484664              0.881878          75.510
# 2013-09-12 14:46:00         0.739090             -0.484664          75.615
# 2013-09-12 14:47:00         0.139432              0.739090          75.570
#
#                          pca0      pca1
# datetime
# 2013-09-12 14:43:00  0.020215  0.035008
# 2013-09-12 14:44:00  0.029924  0.015246
# 2013-09-12 14:45:00  0.038071  0.006379
# 2013-09-12 14:46:00  0.000567  0.017207
# 2013-09-12 14:47:00  0.001962 -0.040099
#
# [5 rows x 61 columns]

# %%
gdf_columns = ['gdf_' + str(i) for i in range(0, 50)]

plt.figure(figsize=(16, 8))
ax = sns.boxplot(data=df[gdf_columns])

_ = ax.set_xticklabels([g.replace('_', ' ').upper() for g in gdf_columns], rotation=45)

plt.title('Distribution of gdf features for stock ' + str(stock))
plt.xlabel('GDF feature')
plt.ylabel('')
# Out:
# Text(0,0.5,'')

# %%
gdf_columns = ['gdf_' + str(i) for i in range(0, 50)]

plt.figure(figsize=(16, 8))
ax = sns.boxplot(data=df[pca_cols])

_ = ax.set_xticklabels([g.replace('_', ' ').upper() for g in pca_cols], rotation=45)

plt.title('Distribution of gdf features for stock ' + str(stock))
plt.xlabel('GDF feature')
plt.ylabel('')
# Out:
# Text(0,0.5,'')

# %%
for g in gdf_columns[::9]:
    sns.distplot(df[g], label=g)
plt.legend()

# %% [markdown]
# ## Predictions

# %%
def get_kernel_from_method(method):
    return method.split('_')[1]

class CFR():
    def __init__(self, clf, feature_name, is_svm=True):
        self.clf = clf
        self.feature_name = feature_name
        self.is_svm = is_svm

    def get_result(self, gdf_df, should_validate=False, method=None):
        if self.is_svm:
            return gdf_df.train_svm(C=self.clf.C, gamma=self.clf.gamma, coef0=self.clf.coef0, 
                                    kernel=self.clf.kernel, 
                                    feature_name=self.feature_name, should_validate=should_validate)
        else:
            res = gdf_df.train_log(self.clf, self.feature_name, should_validate=should_validate)
            if method:
                res['kernel'] = method
            return res

# %% [markdown]
# ### Queue Imbalance - LOGIT, SVM (linear, rbf, sigmoid)

# %%
def get_best_svm_results_for_queue_imbalance(s, features):
    df_res = pd.read_csv('res_{}_prev_queue_imbalance.csv'.format(s))
    df_res= df_res[df_res['features'] == features]
    df_res= df_res[df_res['method'] != 'logistic']
    df_res['stock'] = [s for i in range(len(df_res))]
    columns_to_mean = ['f1', 'kappa', 'matthews', 
       'precision', 'recall', 'roc_auc', 'train_f1', 'train_kappa',
       'train_matthews', 'train_precision', 'train_recall', 'train_roc_auc']
    for c in columns_to_mean:
        cc = []
        for i, row in df_res.iterrows():
            from ast import literal_eval
            cc.append(np.array(literal_eval(row[c])).mean())
        df_res[c] = cc

    return df_res.sort_values(by='matthews', ascending=False).groupby('method').head(1)

# %%
df_best_svm_que = get_best_svm_results_for_queue_imbalance(stock, features='queue_imbalance')

# %%
log_que_clfs = [
    CFR(clf=LogisticRegression(), feature_name='que', is_svm=False),
]

svm_que_clfs = [
    CFR(
        SVC(kernel=get_kernel_from_method(row['method']), 
            C=row['c'], 
            gamma=row['gamma'], 
            coef0=row['coef0']), feature_name='que') 
                for i, row in df_best_svm_que.iterrows()]

# %%
res = []
for clf in log_que_clfs + svm_que_clfs:
    r = clf.get_result(gdf_dfs[0])
    res.append(r)
df_res_que = pd.DataFrame(res)
df_res_que
# Out:
#       C  coef0 features   gamma    kernel stock   test_f1  test_kappa  \
# 0   NaN    NaN      que     NaN  logistic  9064  0.579029    0.090139
# 1  1.00    1.0      que     0.1   sigmoid  9064  0.527442    0.088410
# 2  0.01    NaN      que  1000.0       rbf  9064  0.674475    0.000000
# 3  0.10    NaN      que     NaN    linear  9064  0.566794    0.090427
#
#    test_matthews  test_precision  test_recall  test_roc_auc  train_f1  \
# 0       0.090806        0.548330     0.613368      0.544973  0.561199
# 1       0.088884        0.557257     0.500655      0.544286  0.528819
# 2       0.000000        0.508836     1.000000      0.500000  0.672457
# 3       0.090598        0.550680     0.583879      0.545164  0.550061
#
#    train_kappa  train_matthews  train_precision  train_recall  train_roc_auc
# 0     0.081829        0.081998         0.544484      0.578973       0.540880
# 1     0.089358        0.089734         0.555073      0.504936       0.544733
# 2     0.000000        0.000000         0.506542      1.000000       0.500000
# 3     0.079027        0.079042         0.544780      0.555446       0.539503

# %% [markdown]
# ### Queue Imbalance and Prev Queue Imbalance

# %%
df_best_svm_prev_que = get_best_svm_results_for_queue_imbalance(
    stock, features='queue_imbalance, prev_queue_imbalance')

# %%
prev_que_log_clfs = [
    CFR(clf=LogisticRegression(), feature_name='que_prev', is_svm=False),
]

svm_prev_que_clfs = [
    CFR(
        SVC(kernel=get_kernel_from_method(row['method']), 
            C=row['c'], 
            gamma=row['gamma'], 
            coef0=row['coef0']), feature_name='que_prev') 
                for i, row in df_best_svm_prev_que.iterrows()]

# %%
res = []
for clf in prev_que_log_clfs + svm_prev_que_clfs:
    r = clf.get_result(gdf_dfs[0])
    res.append(r)
df_res_que_prev = pd.DataFrame(res)
df_res_que_prev
# Out:
#        C  coef0  features  gamma    kernel stock   test_f1  test_kappa  \
# 0    NaN    NaN  que_prev    NaN  logistic  9064  0.574741    0.093263
# 1   10.0    NaN  que_prev   0.10       rbf  9064  0.564593    0.088520
# 2  100.0    0.1  que_prev   0.01   sigmoid  9064  0.589474    0.086472
# 3  100.0    NaN  que_prev    NaN    linear  9064  0.565231    0.089856
#
#    test_matthews  test_precision  test_recall  test_roc_auc  train_f1  \
# 0       0.093668        0.550751     0.600917      0.546555  0.561303
# 1       0.088657        0.550031     0.579948      0.544217  0.554779
# 2       0.087952        0.544747     0.642202      0.543097  0.580360
# 3       0.089994        0.550653     0.580603      0.544884  0.552280
#
#    train_kappa  train_matthews  train_precision  train_recall  train_roc_auc
# 0     0.083023        0.083183         0.545116      0.578480       0.541478
# 1     0.086473        0.086499         0.548185      0.561533       0.543222
# 2     0.080508        0.081563         0.540779      0.626193       0.540170
# 3     0.083185        0.083203         0.546759      0.557914       0.541581

# %% [markdown]
# ### GDF Plain

# %%
df_gdf_plain_res = pd.DataFrame()
gdf_results_dir = '../gaussian_filter/data_res_9061_len15000'
results_files = os.listdir(gdf_results_dir)
results_files = [f for f in results_files if stock in f and 'partial' not in f]
for f in results_files:
    temp_df = pd.read_csv(os.path.join(gdf_results_dir, f))
    df_gdf_plain_res = df_gdf_plain_res.append(temp_df)
print(df_gdf_plain_res.columns)
df_gdf_plain_res.sort_values(by='matthews', ascending=False).groupby('kernel').head(1)
# Out:
# Index(['Unnamed: 0', 'C', 'coef0', 'f1', 'features', 'gamma', 'kappa',
#        'kernel', 'matthews', 'precision', 'recall', 'roc_auc', 'stock',
#        'test_f1', 'test_kappa', 'test_matthews', 'test_precision',
#        'test_recall', 'test_roc_auc', 'train_f1', 'train_kappa',
#        'train_matthews', 'train_precision', 'train_recall', 'train_roc_auc'],
#       dtype='object')
#     Unnamed: 0       C  coef0        f1   features  gamma     kappa  kernel  \
# 32          32  10.000    NaN  0.322123  gdf_23-27   10.0  0.031676     rbf
# 0            0   0.001    NaN  0.068039  gdf_23-27    NaN  0.000000  linear
#
#     matthews  precision      ...        test_matthews  test_precision  \
# 32  0.041847   0.441331      ...              0.05433        0.539181
# 0   0.000000   0.049032      ...              0.00000        0.000000
#
#     test_recall  test_roc_auc  train_f1  train_kappa  train_matthews  \
# 32     0.309812      0.524529  0.313378     0.034542        0.039485
# 0      0.000000      0.500000  0.074795     0.000000        0.000000
#
#     train_precision  train_recall  train_roc_auc
# 32         0.414109      0.294915       0.517164
# 0          0.056371      0.111111       0.500000
#
# [2 rows x 25 columns]

# %%
r = 1.0
s = 0.1
C = 1.0 
gamma = 10000.0
filename = 'data_gdf/gdf_{}_len{}_r{}_s{}_K{}.csv'.format(stock, length, r, s, K)

# %% [markdown]
# ### GDF with PCA

# %%
df_gdf_res = pd.DataFrame()
gdf_results_dir = '../gdf_pca/res_pca_gdf3_15000'
results_files = os.listdir(gdf_results_dir)
results_files = [f for f in results_files if stock in f and 'partial' not in f]
for f in results_files:
    temp_df = pd.read_csv(os.path.join(gdf_results_dir, f))
    df_gdf_res = df_gdf_res.append(temp_df)

df_gdf_res.sort_values(by='matthews', ascending=False).groupby('kernel').head(2)
# Out:
#     Unnamed: 0      C  coef0        f1      features  gamma     kappa  \
# 19          19  100.0    1.0  0.523379  pca_gdf_que3   0.01  0.088409
# 19          19  100.0    1.0  0.522823  pca_gdf_que3   0.01  0.086601
# 4            4   10.0    NaN  0.551001  pca_gdf_que3    NaN  0.086377
# 3            3    1.0    NaN  0.550228  pca_gdf_que3    NaN  0.086341
# 30          30   10.0    NaN  0.570978  pca_gdf_que3   0.10  0.085041
# 17          17    0.1    NaN  0.557671  pca_gdf_que3   1.00  0.085519
#
#      kernel  matthews  precision      ...        test_matthews  \
# 19  sigmoid  0.089446   0.557420      ...             0.090150
# 19  sigmoid  0.087608   0.556519      ...             0.092460
# 4    linear  0.086634   0.550605      ...             0.091219
# 3    linear  0.086564   0.550713      ...             0.089204
# 30      rbf  0.086370   0.546479      ...             0.090129
# 17      rbf  0.085808   0.548548      ...             0.087274
#
#     test_precision  test_recall  test_roc_auc  train_f1  train_kappa  \
# 19        0.563636     0.446920      0.544234  0.540548     0.082789
# 19        0.565471     0.444299      0.545299  0.540720     0.083171
# 4         0.550769     0.586501      0.545457  0.563532     0.076295
# 3         0.549815     0.585845      0.544450  0.563029     0.076850
# 30        0.548009     0.613368      0.544634  0.578721     0.069239
# 17        0.544248     0.644823      0.542710  0.569393     0.075496
#
#     train_matthews  train_precision  train_recall  train_roc_auc
# 19        0.083271         0.553571      0.530595       0.541437
# 19        0.083631         0.553788      0.530637       0.541630
# 4         0.076560         0.545617      0.583202       0.538087
# 3         0.077085         0.545946      0.581626       0.538366
# 30        0.070312         0.540489      0.625412       0.534523
# 17        0.075915         0.544304      0.597276       0.537675
#
# [6 rows x 25 columns]

# %%
df_gdf_res = pd.DataFrame()
gdf_results_dir = '../gdf_pca/res_pca1_gdf_que_15000'
results_files = os.listdir(gdf_results_dir)
results_files = [f for f in results_files if stock in f and 'partial' not in f]
for f in results_files:
    temp_df = pd.read_csv(os.path.join(gdf_results_dir, f))
    df_gdf_res = df_gdf_res.append(temp_df)

df_gdf_res.sort_values(by='matthews', ascending=False).groupby('kernel').head(2)
# Out:
#     Unnamed: 0       C  coef0        f1          features  gamma     kappa  \
# 44          44  1000.0    NaN  0.477132  pca_gdf_que_pca1   0.10  0.099900
# 23          23     1.0    NaN  0.456378  pca_gdf_que_pca1   0.10  0.097769
# 4            4    10.0    NaN  0.537194  pca_gdf_que_pca1    NaN  0.099814
# 6            6  1000.0    NaN  0.538406  pca_gdf_que_pca1    NaN  0.099086
# 18          18   100.0   0.01  0.539035  pca_gdf_que_pca1   0.01  0.098381
# 18          18   100.0   0.01  0.538178  pca_gdf_que_pca1   0.01  0.096593
#
#      kernel  matthews  precision      ...        test_matthews  \
# 44      rbf  0.106379   0.567579      ...             0.055509
# 23      rbf  0.105979   0.571852      ...             0.058322
# 4    linear  0.101237   0.548870      ...             0.065428
# 6    linear  0.100447   0.548253      ...             0.066776
# 18  sigmoid  0.099658   0.547613      ...             0.069466
# 18  sigmoid  0.097936   0.546691      ...             0.070137
#
#     test_precision  test_recall  test_roc_auc  train_f1  train_kappa  \
# 44        0.531858     0.403898      0.526899  0.473722     0.088808
# 23        0.536873     0.366935      0.527611  0.451024     0.085731
# 4         0.530271     0.512097      0.532686  0.534314     0.090968
# 6         0.530881     0.514113      0.533364  0.534781     0.092373
# 18        0.532135     0.517473      0.534713  0.535243     0.091331
# 18        0.532459     0.518145      0.535049  0.535690     0.091774
#
#     train_matthews  train_precision  train_recall  train_roc_auc
# 44        0.091659         0.547815      0.421721       0.544120
# 23        0.090436         0.551350      0.387453       0.542527
# 4         0.091016         0.535531      0.533336       0.545457
# 6         0.092419         0.536363      0.533436       0.546156
# 18        0.091375         0.535639      0.535066       0.545641
# 18        0.091821         0.535831      0.535788       0.545863
#
# [6 rows x 25 columns]

# %%
df_gdf_res = pd.DataFrame()
gdf_results_dir = '../gdf_pca/res_pca2_gdf_que_15000'
results_files = os.listdir(gdf_results_dir)
results_files = [f for f in results_files if stock in f and 'partial' not in f]
for f in results_files:
    temp_df = pd.read_csv(os.path.join(gdf_results_dir, f))
    df_gdf_res = df_gdf_res.append(temp_df)

df_gdf_res.sort_values(by='matthews', ascending=False).groupby('kernel').head(2)
# Out:
#     Unnamed: 0       C  coef0        f1          features  gamma     kappa  \
# 44          44  1000.0    NaN  0.475799  pca_gdf_que_pca2   0.10  0.099562
# 43          43  1000.0    NaN  0.434382  pca_gdf_que_pca2   0.01  0.095329
# 4            4    10.0    NaN  0.536402  pca_gdf_que_pca2    NaN  0.099035
# 4            4    10.0    NaN  0.536112  pca_gdf_que_pca2    NaN  0.098660
# 18          18   100.0   0.01  0.538007  pca_gdf_que_pca2   0.01  0.096916
# 18          18   100.0   0.01  0.537919  pca_gdf_que_pca2   0.01  0.096853
#
#      kernel  matthews  precision      ...        test_matthews  \
# 44      rbf  0.106222   0.567937      ...             0.053448
# 43      rbf  0.105561   0.576707      ...             0.043403
# 4    linear  0.100538   0.548718      ...             0.065428
# 4    linear  0.100074   0.548525      ...             0.066756
# 18  sigmoid  0.098218   0.546866      ...             0.069459
# 18  sigmoid  0.098162   0.546872      ...             0.067440
#
#     test_precision  test_recall  test_roc_auc  train_f1  train_kappa  \
# 44        0.530558     0.402554      0.525896  0.472714     0.088908
# 43        0.528711     0.327957      0.520034  0.430563     0.083669
# 4         0.530271     0.512097      0.532686  0.533900     0.091330
# 4         0.531010     0.512097      0.533348  0.534078     0.091387
# 18        0.532180     0.516801      0.534708  0.534599     0.090397
# 18        0.531250     0.514113      0.533694  0.534586     0.090436
#
#     train_matthews  train_precision  train_recall  train_roc_auc
# 44        0.091790         0.548021      0.419973       0.544171
# 43        0.090262         0.556109      0.357344       0.541448
# 4         0.091371         0.535897      0.532122       0.545637
# 4         0.091426         0.535898      0.532470       0.545666
# 18        0.090441         0.535131      0.534288       0.545174
# 18        0.090473         0.535199      0.534168       0.545195
#
# [6 rows x 25 columns]

# %%
from sklearn.neural_network import MLPClassifier
alphas = [0.01, 0.1, 1.0]
activations = ['tanh']
solvers = ['adam']
hidden_layer_sizes = [(3, 3), (10, 3), (3, 10), (10, 10)]
features = ['pca_gdf_que_prev3', 'pca_gdf_que_prev5']
res1 = []

for feature in features:
    for hidden_layer_size in hidden_layer_sizes:
        for solver in solvers:
            for activation in activations:
                for alpha in alphas:
                    clf = MLPClassifier(solver=solver, alpha=alpha, activation=activation,
                                              hidden_layer_sizes=hidden_layer_size, random_state=1)

                    c = CFR(clf=clf, feature_name=feature, is_svm=False)
                    r = c.get_result(gdf_dfs[0], should_validate=True, method='mlp')
                    res1.append({**r, 'hidden_layer_size': hidden_layer_size, 
                                'alpha': alpha, 'activation': activation, 'solver': solver})
pd.DataFrame(res1)
# Out:
#    activation  alpha        f1           features hidden_layer_size     kappa  \
# 0        tanh   0.01  0.570339  pca_gdf_que_prev3            (3, 3)  0.078279
# 1        tanh   0.10  0.569991  pca_gdf_que_prev3            (3, 3)  0.079334
# 2        tanh   1.00  0.577422  pca_gdf_que_prev3            (3, 3)  0.091329
# 3        tanh   0.01  0.558315  pca_gdf_que_prev3           (10, 3)  0.080048
# 4        tanh   0.10  0.560690  pca_gdf_que_prev3           (10, 3)  0.080137
# 5        tanh   1.00  0.576409  pca_gdf_que_prev3           (10, 3)  0.084797
# 6        tanh   0.01  0.561753  pca_gdf_que_prev3           (3, 10)  0.074214
# 7        tanh   0.10  0.561949  pca_gdf_que_prev3           (3, 10)  0.072374
# 8        tanh   1.00  0.576540  pca_gdf_que_prev3           (3, 10)  0.080281
# 9        tanh   0.01  0.565321  pca_gdf_que_prev3          (10, 10)  0.078243
# 10       tanh   0.10  0.562407  pca_gdf_que_prev3          (10, 10)  0.077496
# 11       tanh   1.00  0.572586  pca_gdf_que_prev3          (10, 10)  0.085062
# 12       tanh   0.01  0.571195  pca_gdf_que_prev5            (3, 3)  0.083656
# 13       tanh   0.10  0.570911  pca_gdf_que_prev5            (3, 3)  0.084682
# 14       tanh   1.00  0.576149  pca_gdf_que_prev5            (3, 3)  0.087136
# 15       tanh   0.01  0.554063  pca_gdf_que_prev5           (10, 3)  0.087569
# 16       tanh   0.10  0.555242  pca_gdf_que_prev5           (10, 3)  0.089097
# 17       tanh   1.00  0.573317  pca_gdf_que_prev5           (10, 3)  0.086289
# 18       tanh   0.01  0.544045  pca_gdf_que_prev5           (3, 10)  0.069723
# 19       tanh   0.10  0.543430  pca_gdf_que_prev5           (3, 10)  0.070126
# 20       tanh   1.00  0.573119  pca_gdf_que_prev5           (3, 10)  0.077320
# 21       tanh   0.01  0.562723  pca_gdf_que_prev5          (10, 10)  0.082643
# 22       tanh   0.10  0.565409  pca_gdf_que_prev5          (10, 10)  0.081266
# 23       tanh   1.00  0.572231  pca_gdf_que_prev5          (10, 10)  0.079238
#
#    kernel  matthews  precision    recall      ...        test_matthews  \
# 0     mlp  0.079490   0.543287  0.604618      ...             0.099331
# 1     mlp  0.080537   0.543883  0.603212      ...             0.098342
# 2     mlp  0.092316   0.548571  0.611506      ...             0.094537
# 3     mlp  0.081259   0.546466  0.576556      ...             0.093320
# 4     mlp  0.081317   0.546109  0.581762      ...             0.097090
# 5     mlp  0.086290   0.545379  0.615323      ...             0.106088
# 6     mlp  0.076105   0.542021  0.593032      ...             0.099498
# 7     mlp  0.074206   0.540977  0.594420      ...             0.096783
# 8     mlp  0.082275   0.542935  0.620249      ...             0.098767
# 9     mlp  0.079232   0.544113  0.593434      ...             0.100846
# 10    mlp  0.078363   0.544508  0.586926      ...             0.097557
# 11    mlp  0.086498   0.546138  0.607337      ...             0.099342
# 12    mlp  0.084536   0.545944  0.601591      ...             0.089592
# 13    mlp  0.085570   0.546469  0.600292      ...             0.085485
# 14    mlp  0.088193   0.546678  0.611507      ...             0.100319
# 15    mlp  0.088055   0.550621  0.560102      ...             0.101753
# 16    mlp  0.089621   0.551271  0.562139      ...             0.097590
# 17    mlp  0.087982   0.546637  0.609083      ...             0.094493
# 18    mlp  0.070434   0.542262  0.558303      ...             0.093774
# 19    mlp  0.070841   0.542771  0.556588      ...             0.089065
# 20    mlp  0.079143   0.542160  0.615237      ...             0.094836
# 21    mlp  0.083355   0.547042  0.583439      ...             0.092779
# 22    mlp  0.082276   0.545412  0.591621      ...             0.093763
# 23    mlp  0.080819   0.543192  0.610124      ...             0.097269
#
#    test_precision test_recall  test_roc_auc  train_f1  train_kappa  \
# 0        0.546359    0.683486      0.547785  0.579971     0.072443
# 1        0.547363    0.666448      0.547752  0.579135     0.073671
# 2        0.542313    0.709699      0.544598  0.580013     0.073141
# 3        0.554397    0.557667      0.546654  0.560749     0.074851
# 4        0.555484    0.567497      0.548514  0.565370     0.075026
# 5        0.549550    0.679554      0.551250  0.584118     0.072844
# 6        0.550056    0.640891      0.548891  0.572874     0.061904
# 7        0.548931    0.639581      0.547557  0.574097     0.061278
# 8        0.545691    0.688729      0.547351  0.588285     0.070968
# 9        0.551136    0.635649      0.549664  0.576157     0.076462
# 10       0.554994    0.575360      0.548712  0.573830     0.076147
# 11       0.542913    0.725426      0.546352  0.581187     0.072369
# 12       0.548657    0.602228      0.544495  0.572657     0.075809
# 13       0.546422    0.605505      0.542399  0.572287     0.074171
# 14       0.545782    0.695282      0.547912  0.582174     0.076772
# 15       0.557692    0.570118      0.550843  0.557282     0.075634
# 16       0.555133    0.574050      0.548736  0.559477     0.073541
# 17       0.542398    0.708388      0.544622  0.582524     0.071505
# 18       0.551368    0.594364      0.546673  0.562978     0.065152
# 19       0.549150    0.593054      0.544320  0.562197     0.066033
# 20       0.546543    0.657929      0.546208  0.585279     0.070985
# 21       0.548724    0.619921      0.545874  0.568091     0.075362
# 22       0.551305    0.595020      0.546661  0.573724     0.076194
# 23       0.542074    0.726081      0.545322  0.584187     0.072376
#
#     train_matthews  train_precision  train_recall  train_roc_auc
# 0         0.073449         0.541315      0.625270       0.536092
# 1         0.074616         0.541989      0.622444       0.536708
# 2         0.074116         0.541740      0.624839       0.536446
# 3         0.075201         0.546231      0.579462       0.537393
# 4         0.075469         0.545577      0.589992       0.537463
# 5         0.074108         0.541242      0.635775       0.536284
# 6         0.063047         0.537660      0.617735       0.530853
# 7         0.062092         0.537494      0.620837       0.530553
# 8         0.072841         0.539809      0.648629       0.535322
# 9         0.077473         0.544051      0.614569       0.538113
# 10        0.077161         0.544317      0.609663       0.537967
# 11        0.073704         0.541469      0.629824       0.536045
# 12        0.076379         0.544188      0.605138       0.537814
# 13        0.074740         0.543414      0.605259       0.536996
# 14        0.077787         0.543210      0.627620       0.538254
# 15        0.075843         0.546669      0.570139       0.537783
# 16        0.073750         0.545258      0.576265       0.536730
# 17        0.072849         0.541021      0.633781       0.535620
# 18        0.065844         0.540453      0.591360       0.532507
# 19        0.066717         0.540977      0.589188       0.532948
# 20        0.072845         0.540294      0.641823       0.535337
# 21        0.076046         0.544541      0.595962       0.537588
# 22        0.077083         0.544298      0.608651       0.537992
# 23        0.073796         0.541175      0.637083       0.536047
#
# [24 rows x 25 columns]

# %%
df_res1 = pd.DataFrame(res1)
df_res1.sort_values(by='test_matthews', ascending=False).head()
# Out:
#    activation  alpha        f1           features hidden_layer_size     kappa  \
# 5        tanh   1.00  0.576409  pca_gdf_que_prev3           (10, 3)  0.084797
# 15       tanh   0.01  0.554063  pca_gdf_que_prev5           (10, 3)  0.087569
# 9        tanh   0.01  0.565321  pca_gdf_que_prev3          (10, 10)  0.078243
# 14       tanh   1.00  0.576149  pca_gdf_que_prev5            (3, 3)  0.087136
# 6        tanh   0.01  0.561753  pca_gdf_que_prev3           (3, 10)  0.074214
#
#    kernel  matthews  precision    recall      ...        test_matthews  \
# 5     mlp  0.086290   0.545379  0.615323      ...             0.106088
# 15    mlp  0.088055   0.550621  0.560102      ...             0.101753
# 9     mlp  0.079232   0.544113  0.593434      ...             0.100846
# 14    mlp  0.088193   0.546678  0.611507      ...             0.100319
# 6     mlp  0.076105   0.542021  0.593032      ...             0.099498
#
#    test_precision test_recall  test_roc_auc  train_f1  train_kappa  \
# 5        0.549550    0.679554      0.551250  0.584118     0.072844
# 15       0.557692    0.570118      0.550843  0.557282     0.075634
# 9        0.551136    0.635649      0.549664  0.576157     0.076462
# 14       0.545782    0.695282      0.547912  0.582174     0.076772
# 6        0.550056    0.640891      0.548891  0.572874     0.061904
#
#     train_matthews  train_precision  train_recall  train_roc_auc
# 5         0.074108         0.541242      0.635775       0.536284
# 15        0.075843         0.546669      0.570139       0.537783
# 9         0.077473         0.544051      0.614569       0.538113
# 14        0.077787         0.543210      0.627620       0.538254
# 6         0.063047         0.537660      0.617735       0.530853
#
# [5 rows x 25 columns]

# %%
from sklearn.neural_network import MLPClassifier
alphas = [0.0001, 0.001, 0.1, 1.0] # sgd with alpha = 1
activations = ['identity', 'logistic', 'tanh', 'relu']
solvers = ['adam', 'sgd']
hidden_layer_sizes = [(3, 3), (10, 3), (3, 10), (10, 10)]

res = []

for hidden_layer_size in hidden_layer_sizes:
    for solver in solvers:
        for activation in activations:
            for alpha in alphas:
                clf = MLPClassifier(solver=solver, alpha=alpha, activation=activation,
                                          hidden_layer_sizes=hidden_layer_size, random_state=1)

                c = CFR(clf=clf, feature_name='pca_gdf_que_prev10', is_svm=False)
                r = c.get_result(gdf_dfs[0], should_validate=True, method='mlp')
                res.append({**r, 'hidden_layer_size': hidden_layer_size, 
                            'alpha': alpha, 'activation': activation, 'solver': solver})
pd.DataFrame(res)
# Out:
#     activation   alpha        f1            features hidden_layer_size  \
# 0     identity  0.0001  0.573677  pca_gdf_que_prev10            (3, 3)
# 1     identity  0.0010  0.573755  pca_gdf_que_prev10            (3, 3)
# 2     identity  0.1000  0.573102  pca_gdf_que_prev10            (3, 3)
# 3     identity  1.0000  0.566741  pca_gdf_que_prev10            (3, 3)
# 4     logistic  0.0001  0.668854  pca_gdf_que_prev10            (3, 3)
# 5     logistic  0.0010  0.668854  pca_gdf_que_prev10            (3, 3)
# 6     logistic  0.1000  0.667034  pca_gdf_que_prev10            (3, 3)
# 7     logistic  1.0000  0.673830  pca_gdf_que_prev10            (3, 3)
# 8         tanh  0.0001  0.584304  pca_gdf_que_prev10            (3, 3)
# 9         tanh  0.0010  0.584204  pca_gdf_que_prev10            (3, 3)
# 10        tanh  0.1000  0.587953  pca_gdf_que_prev10            (3, 3)
# 11        tanh  1.0000  0.592026  pca_gdf_que_prev10            (3, 3)
# 12        relu  0.0001  0.564436  pca_gdf_que_prev10            (3, 3)
# 13        relu  0.0010  0.564575  pca_gdf_que_prev10            (3, 3)
# 14        relu  0.1000  0.560342  pca_gdf_que_prev10            (3, 3)
# 15        relu  1.0000  0.561740  pca_gdf_que_prev10            (3, 3)
# 16    identity  0.0001  0.552578  pca_gdf_que_prev10            (3, 3)
# 17    identity  0.0010  0.552578  pca_gdf_que_prev10            (3, 3)
# 18    identity  0.1000  0.553645  pca_gdf_que_prev10            (3, 3)
# 19    identity  1.0000  0.568680  pca_gdf_que_prev10            (3, 3)
# 20    logistic  0.0001  0.431212  pca_gdf_que_prev10            (3, 3)
# 21    logistic  0.0010  0.430987  pca_gdf_que_prev10            (3, 3)
# 22    logistic  0.1000  0.430425  pca_gdf_que_prev10            (3, 3)
# 23    logistic  1.0000  0.420508  pca_gdf_que_prev10            (3, 3)
# 24        tanh  0.0001  0.583806  pca_gdf_que_prev10            (3, 3)
# 25        tanh  0.0010  0.583806  pca_gdf_que_prev10            (3, 3)
# 26        tanh  0.1000  0.584629  pca_gdf_que_prev10            (3, 3)
# 27        tanh  1.0000  0.603021  pca_gdf_que_prev10            (3, 3)
# 28        relu  0.0001  0.512785  pca_gdf_que_prev10            (3, 3)
# 29        relu  0.0010  0.512834  pca_gdf_que_prev10            (3, 3)
# ..         ...     ...       ...                 ...               ...
# 98    identity  0.1000  0.571732  pca_gdf_que_prev10          (10, 10)
# 99    identity  1.0000  0.574307  pca_gdf_que_prev10          (10, 10)
# 100   logistic  0.0001  0.666794  pca_gdf_que_prev10          (10, 10)
# 101   logistic  0.0010  0.666531  pca_gdf_que_prev10          (10, 10)
# 102   logistic  0.1000  0.673876  pca_gdf_que_prev10          (10, 10)
# 103   logistic  1.0000  0.673830  pca_gdf_que_prev10          (10, 10)
# 104       tanh  0.0001  0.558415  pca_gdf_que_prev10          (10, 10)
# 105       tanh  0.0010  0.558415  pca_gdf_que_prev10          (10, 10)
# 106       tanh  0.1000  0.571426  pca_gdf_que_prev10          (10, 10)
# 107       tanh  1.0000  0.571503  pca_gdf_que_prev10          (10, 10)
# 108       relu  0.0001  0.543164  pca_gdf_que_prev10          (10, 10)
# 109       relu  0.0010  0.543065  pca_gdf_que_prev10          (10, 10)
# 110       relu  0.1000  0.550663  pca_gdf_que_prev10          (10, 10)
# 111       relu  1.0000  0.570097  pca_gdf_que_prev10          (10, 10)
# 112   identity  0.0001  0.543098  pca_gdf_que_prev10          (10, 10)
# 113   identity  0.0010  0.543098  pca_gdf_que_prev10          (10, 10)
# 114   identity  0.1000  0.540457  pca_gdf_que_prev10          (10, 10)
# 115   identity  1.0000  0.548062  pca_gdf_que_prev10          (10, 10)
# 116   logistic  0.0001  0.673830  pca_gdf_que_prev10          (10, 10)
# 117   logistic  0.0010  0.673830  pca_gdf_que_prev10          (10, 10)
# 118   logistic  0.1000  0.673830  pca_gdf_que_prev10          (10, 10)
# 119   logistic  1.0000  0.673830  pca_gdf_que_prev10          (10, 10)
# 120       tanh  0.0001  0.560818  pca_gdf_que_prev10          (10, 10)
# 121       tanh  0.0010  0.560818  pca_gdf_que_prev10          (10, 10)
# 122       tanh  0.1000  0.560486  pca_gdf_que_prev10          (10, 10)
# 123       tanh  1.0000  0.553855  pca_gdf_que_prev10          (10, 10)
# 124       relu  0.0001  0.598309  pca_gdf_que_prev10          (10, 10)
# 125       relu  0.0010  0.598309  pca_gdf_que_prev10          (10, 10)
# 126       relu  0.1000  0.598147  pca_gdf_que_prev10          (10, 10)
# 127       relu  1.0000  0.569784  pca_gdf_que_prev10          (10, 10)
#
#         kappa kernel  matthews  precision    recall      ...        \
# 0    0.068123    mlp  0.069010   0.538291  0.618373      ...
# 1    0.068110    mlp  0.069002   0.538264  0.618572      ...
# 2    0.065462    mlp  0.066223   0.537044  0.618351      ...
# 3    0.067877    mlp  0.068548   0.538824  0.601387      ...
# 4    0.005006    mlp  0.005860   0.509816  0.977739      ...
# 5    0.005006    mlp  0.005860   0.509816  0.977739      ...
# 6    0.004722    mlp  0.005202   0.509832  0.972319      ...
# 7    0.000000    mlp  0.000000   0.508257  1.000000      ...
# 8    0.062278    mlp  0.064358   0.535298  0.655525      ...
# 9    0.062070    mlp  0.064111   0.535242  0.655317      ...
# 10   0.062387    mlp  0.064004   0.535346  0.664446      ...
# 11   0.060287    mlp  0.061671   0.533305  0.673689      ...
# 12   0.036437    mlp  0.037995   0.523910  0.618444      ...
# 13   0.036629    mlp  0.038160   0.523997  0.618633      ...
# 14   0.038590    mlp  0.040073   0.524866  0.607311      ...
# 15   0.058069    mlp  0.058579   0.534366  0.596109      ...
# 16   0.012753    mlp  0.012808   0.514941  0.601163      ...
# 17   0.012753    mlp  0.012808   0.514941  0.601163      ...
# 18   0.012750    mlp  0.012843   0.514810  0.603623      ...
# 19   0.023809    mlp  0.024554   0.518439  0.633913      ...
# 20  -0.019863    mlp -0.023064   0.380468  0.578539      ...
# 21  -0.020066    mlp -0.023301   0.380258  0.578335      ...
# 22  -0.017526    mlp -0.019646   0.381954  0.576933      ...
# 23  -0.015690    mlp -0.018790   0.378734  0.575056      ...
# 24  -0.025285    mlp -0.027500   0.499178  0.706588      ...
# 25  -0.025285    mlp -0.027500   0.499178  0.706588      ...
# 26  -0.024962    mlp -0.027217   0.499339  0.708582      ...
# 27  -0.006290    mlp -0.004585   0.505460  0.753711      ...
# 28   0.009077    mlp  0.009024   0.513148  0.515761      ...
# 29   0.009282    mlp  0.009229   0.513262  0.515761      ...
# ..        ...    ...       ...        ...       ...      ...
# 98   0.081205    mlp  0.083063   0.544169  0.609013      ...
# 99   0.074990    mlp  0.076587   0.540744  0.617516      ...
# 100 -0.001167    mlp -0.001379   0.507897  0.975610      ...
# 101 -0.001786    mlp -0.002109   0.507705  0.975223      ...
# 102  0.000220    mlp  0.003499   0.508310  1.000000      ...
# 103  0.000000    mlp  0.000000   0.508257  1.000000      ...
# 104  0.081022    mlp  0.081679   0.546741  0.575560      ...
# 105  0.081022    mlp  0.081679   0.546741  0.575560      ...
# 106  0.077218    mlp  0.078658   0.542296  0.608614      ...
# 107  0.074153    mlp  0.075562   0.540825  0.611115      ...
# 108  0.072497    mlp  0.072637   0.545235  0.545450      ...
# 109  0.070366    mlp  0.070517   0.543981  0.546644      ...
# 110  0.080270    mlp  0.080299   0.548422  0.556176      ...
# 111  0.071488    mlp  0.072430   0.539880  0.608123      ...
# 112  0.050572    mlp  0.051041   0.527796  0.590631      ...
# 113  0.050572    mlp  0.051041   0.527796  0.590631      ...
# 114  0.049918    mlp  0.050615   0.527976  0.586571      ...
# 115  0.066088    mlp  0.065659   0.537675  0.577559      ...
# 116  0.000000    mlp  0.000000   0.508257  1.000000      ...
# 117  0.000000    mlp  0.000000   0.508257  1.000000      ...
# 118  0.000000    mlp  0.000000   0.508257  1.000000      ...
# 119  0.000000    mlp  0.000000   0.508257  1.000000      ...
# 120  0.042677    mlp  0.043676   0.522531  0.628558      ...
# 121  0.042677    mlp  0.043676   0.522531  0.628558      ...
# 122  0.040360    mlp  0.041249   0.521502  0.629154      ...
# 123  0.062744    mlp  0.061534   0.536294  0.591676      ...
# 124  0.014069    mlp  0.014377   0.512946  0.727603      ...
# 125  0.014069    mlp  0.014377   0.512946  0.727603      ...
# 126  0.014533    mlp  0.014714   0.513166  0.726599      ...
# 127  0.059848    mlp  0.059387   0.535671  0.623127      ...
#
#      test_matthews test_precision test_recall  test_roc_auc  train_f1  \
# 0         0.087307       0.545558    0.627785      0.543017  0.581980
# 1         0.087982       0.545817    0.628440      0.543344  0.581937
# 2         0.098168       0.548835    0.648100      0.548082  0.582399
# 3         0.095133       0.544929    0.679554      0.545819  0.580058
# 4         0.000000       0.508836    1.000000      0.500000  0.669133
# 5         0.000000       0.508836    1.000000      0.500000  0.669078
# 6         0.000000       0.508836    1.000000      0.500000  0.667286
# 7         0.000000       0.508836    1.000000      0.500000  0.676021
# 8         0.092749       0.548331    0.624509      0.545791  0.592944
# 9         0.092745       0.548276    0.625164      0.545779  0.593007
# 10        0.090672       0.546064    0.640891      0.544478  0.594918
# 11        0.099200       0.540000    0.760813      0.544697  0.605414
# 12        0.091699       0.543501    0.679554      0.544122  0.579579
# 13        0.089635       0.542648    0.679554      0.543104  0.579430
# 14        0.094653       0.543950    0.689384      0.545303  0.578024
# 15        0.094251       0.542915    0.700524      0.544763  0.579247
# 16        0.070867       0.536286    0.658585      0.534316  0.572275
# 17        0.070867       0.536286    0.658585      0.534316  0.572232
# 18        0.073642       0.537037    0.665138      0.535556  0.572886
# 19        0.099379       0.544266    0.709043      0.546986  0.580024
# 20        0.000000       0.508836    1.000000      0.500000  0.435761
# 21        0.000000       0.508836    1.000000      0.500000  0.435740
# 22        0.000000       0.508836    1.000000      0.500000  0.433393
# 23        0.000000       0.508836    1.000000      0.500000  0.425527
# 24        0.008792       0.510800    0.836828      0.503275  0.593193
# 25        0.008792       0.510800    0.836828      0.503275  0.593193
# 26        0.011485       0.511405    0.837484      0.504282  0.593061
# 27        0.029312       0.514146    0.893185      0.509389  0.607498
# 28        0.021424       0.517241    0.629096      0.510407  0.533854
# 29        0.021424       0.517241    0.629096      0.510407  0.533831
# ..             ...            ...         ...           ...       ...
# 98        0.094869       0.541728    0.718873      0.544433  0.586901
# 99        0.101388       0.547219    0.683486      0.548804  0.586474
# 100       0.000000       0.508836    1.000000      0.500000  0.669157
# 101       0.000000       0.508836    1.000000      0.500000  0.669140
# 102       0.000000       0.508836    1.000000      0.500000  0.676010
# 103       0.000000       0.508836    1.000000      0.500000  0.676021
# 104       0.099037       0.553153    0.603539      0.549224  0.572315
# 105       0.098361       0.552821    0.603539      0.548884  0.572319
# 106       0.108722       0.548818    0.699869      0.551903  0.586077
# 107       0.095561       0.543645    0.697903      0.545489  0.585092
# 108       0.099414       0.555278    0.582569      0.549601  0.562461
# 109       0.100766       0.555972    0.582569      0.550280  0.563850
# 110       0.096654       0.553627    0.585190      0.548196  0.567006
# 111       0.097561       0.544661    0.695282      0.546555  0.585497
# 112       0.089447       0.540868    0.702490      0.542352  0.578381
# 113       0.089447       0.540868    0.702490      0.542352  0.578381
# 114       0.090161       0.541099    0.703145      0.542679  0.577417
# 115       0.093631       0.544923    0.671691      0.545282  0.579416
# 116       0.000000       0.508836    1.000000      0.500000  0.676021
# 117       0.000000       0.508836    1.000000      0.500000  0.676021
# 118       0.000000       0.508836    1.000000      0.500000  0.676021
# 119       0.000000       0.508836    1.000000      0.500000  0.676021
# 120       0.092742       0.542667    0.695937      0.544167  0.583862
# 121       0.092742       0.542667    0.695937      0.544167  0.583862
# 122       0.094925       0.543235    0.699869      0.545114  0.584546
# 123       0.097345       0.545265    0.686763      0.546708  0.582455
# 124       0.061955       0.533297    0.645478      0.530139  0.601235
# 125       0.061955       0.533297    0.645478      0.530139  0.601306
# 126       0.063313       0.533693    0.648755      0.530759  0.601153
# 127       0.089993       0.545708    0.641547      0.544127  0.576355
#
#      train_kappa  train_matthews  train_precision  train_recall  train_roc_auc
# 0       0.070416        0.071519         0.540432      0.631934       0.535086
# 1       0.070220        0.071322         0.540342      0.631951       0.534989
# 2       0.068927        0.070144         0.539557      0.634130       0.534337
# 3       0.062399        0.063603         0.536588      0.632541       0.531080
# 4      -0.001516       -0.001834         0.510126      0.975140       0.499244
# 5      -0.001617       -0.001955         0.510094      0.975038       0.499193
# 6      -0.003735       -0.004335         0.509376      0.970979       0.498137
# 7       0.000000        0.000000         0.510609      1.000000       0.500000
# 8       0.065117        0.067003         0.538112      0.668618       0.532439
# 9       0.065147        0.067051         0.538108      0.668794       0.532454
# 10      0.058782        0.060830         0.535123      0.678488       0.529271
# 11      0.057486        0.061437         0.532183      0.706040       0.528544
# 12      0.039068        0.040610         0.525886      0.649469       0.519419
# 13      0.038773        0.040294         0.525781      0.649266       0.519272
# 14      0.043969        0.045351         0.528170      0.641505       0.521868
# 15      0.058299        0.059493         0.534607      0.633249       0.529025
# 16      0.012907        0.014374         0.514289      0.647723       0.506377
# 17      0.012818        0.014279         0.514257      0.647661       0.506333
# 18      0.012813        0.014386         0.514178      0.649545       0.506327
# 19      0.021696        0.023950         0.517426      0.663445       0.510737
# 20     -0.008271       -0.012405         0.390175      0.581643       0.495855
# 21     -0.008311       -0.012456         0.390163      0.581603       0.495835
# 22     -0.009395       -0.013720         0.389010      0.578553       0.495290
# 23     -0.006005       -0.010578         0.389688      0.578474       0.496978
# 24     -0.019850       -0.021276         0.503187      0.725750       0.490145
# 25     -0.019850       -0.021276         0.503187      0.725750       0.490145
# 26     -0.020839       -0.022406         0.502848      0.726040       0.489655
# 27     -0.009193       -0.008642         0.506674      0.764939       0.495417
# 28      0.011114        0.011220         0.515430      0.554793       0.505538
# 29      0.011065        0.011172         0.515409      0.554768       0.505514
# ..           ...             ...              ...           ...            ...
# 98      0.078671        0.080347         0.543540      0.639829       0.539175
# 99      0.072219        0.073803         0.540685      0.642780       0.535956
# 100     0.000861        0.001002         0.510893      0.973415       0.500430
# 101     0.000655        0.000764         0.510824      0.973516       0.500327
# 102     0.000002        0.000055         0.510610      0.999950       0.500001
# 103     0.000000        0.000000         0.510609      1.000000       0.500000
# 104     0.078622        0.079358         0.545680      0.603525       0.539212
# 105     0.078463        0.079200         0.545587      0.603637       0.539132
# 106     0.077041        0.078525         0.542752      0.638123       0.538365
# 107     0.073918        0.075399         0.541476      0.637830       0.536804
# 108     0.088916        0.089179         0.552395      0.573701       0.544402
# 109     0.089746        0.090035         0.552631      0.576384       0.544812
# 110     0.088568        0.088965         0.551388      0.584426       0.544203
# 111     0.077513        0.079067         0.542859      0.636727       0.538584
# 112     0.045044        0.044753         0.530043      0.640136       0.522480
# 113     0.045044        0.044753         0.530043      0.640136       0.522480
# 114     0.047924        0.047693         0.531272      0.635970       0.523913
# 115     0.060277        0.060321         0.536940      0.633758       0.530074
# 116     0.000000        0.000000         0.510609      1.000000       0.500000
# 117     0.000000        0.000000         0.510609      1.000000       0.500000
# 118     0.000000        0.000000         0.510609      1.000000       0.500000
# 119     0.000000        0.000000         0.510609      1.000000       0.500000
# 120     0.029990        0.028948         0.523314      0.665740       0.514978
# 121     0.029990        0.028948         0.523314      0.665740       0.514978
# 122     0.030810        0.029826         0.523611      0.667057       0.515385
# 123     0.056433        0.056249         0.534929      0.645576       0.528150
# 124     0.023663        0.031829         0.518969      0.724768       0.511710
# 125     0.023773        0.031946         0.519008      0.724891       0.511765
# 126     0.024755        0.032981         0.519359      0.723696       0.512252
# 127     0.063202        0.067075         0.538265      0.634129       0.531495
#
# [128 rows x 25 columns]

# %%
df_res = pd.DataFrame(res)
df_res.sort_values(by='matthews', ascending=False).groupby('solver').head(2)
# Out:
#    activation  alpha        f1            features hidden_layer_size  \
# 74       tanh    0.1  0.569715  pca_gdf_que_prev10           (3, 10)
# 43       tanh    1.0  0.575302  pca_gdf_que_prev10           (10, 3)
# 59       tanh    1.0  0.556571  pca_gdf_que_prev10           (10, 3)
# 51   identity    1.0  0.555261  pca_gdf_que_prev10           (10, 3)
#
#        kappa kernel  matthews  precision    recall      ...        \
# 74  0.088760    mlp  0.089655   0.548906  0.596496      ...
# 43  0.088112    mlp  0.089363   0.547153  0.610423      ...
# 59  0.082120    mlp  0.083136   0.546447  0.573520      ...
# 51  0.080932    mlp  0.081881   0.546400  0.570518      ...
#
#     test_matthews test_precision test_recall  test_roc_auc  train_f1  \
# 74       0.087435       0.546838    0.612058      0.543300  0.578782
# 43       0.100989       0.546110    0.694626      0.548264  0.582626
# 59       0.103215       0.546571    0.699869      0.549188  0.575981
# 51       0.105669       0.548438    0.690039      0.550722  0.576144
#
#     train_kappa  train_matthews  train_precision  train_recall  train_roc_auc
# 74     0.082120        0.083204         0.546455      0.617093       0.540931
# 43     0.076472        0.077675         0.543057      0.629624       0.538093
# 59     0.063563        0.064365         0.537683      0.620680       0.531677
# 51     0.071044        0.071833         0.541239      0.616558       0.535410
#
# [4 rows x 25 columns]
